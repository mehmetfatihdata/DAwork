# %%
# Basic Libraries
import pandas as pd
import numpy as np

# Libraries for visualizaton
import matplotlib.pyplot as plt
import seaborn as sns

#print(sns.get_dataset_names())

# %%
tips = sns.load_dataset("tips")

# %%
tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %% [markdown]
# ## COUNTPLOT

# %%
sns.countplot (x = "day", data = tips);

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x='day', data=tips)
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.3, p.get_height()+0.5));
    # matplotlib.pyplot.annotate(text, xy, *args, **kwargs)
    # [https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html]

# %%
sns.countplot(x = "day", data = tips, hue = "sex")
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x='day', data=tips, hue="sex")
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+1));

# %%
fig, ax = plt.subplots()
ax = sns.countplot(x='day', data=tips, hue="sex")
for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.1, p.get_height()+1))
    ax.text(p.get_x()+0.1, p.get_height()-3,str(round(p.get_height()/tips.day.count(),2)) )

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.countplot(x='model_year', data=mpg);

# %%
sns.countplot(x = "cylinders", data = mpg);

# %%
sns.countplot(x ="model_year", hue = "origin", data = mpg);

# %% [markdown]
# ## BARPLOT

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.barplot(x = "sex", y = "total_bill", data = tips);

# %%
sns.barplot(x = "sex", y = "total_bill", data = tips, ci = "sd");

# %%
sns.barplot(x = "day", y = "total_bill", data = tips, hue = "sex", ci = "sd");

# %%
tips.groupby(["day", "sex"]).sum()
# Out:
#              total_bill     tip  size
# day  sex
# Thur Male        561.44   89.41    73
#      Female      534.89   82.42    79
# Fri  Male        198.57   26.93    21
#      Female      127.31   25.03    19
# Sat  Male       1227.35  181.95   156
#      Female      551.05   78.45    63
# Sun  Male       1269.46  186.78   163
#      Female      357.70   60.61    53

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
sns.barplot(x="day", y="total_bill", data=tips, ax = ax[0], estimator = (np.count_nonzero))
sns.countplot(x="day", data=tips, ax = ax[1])
plt.tight_layout()

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
sns.barplot(x="day", y="total_bill", data=tips, ax = ax[0])
sns.countplot(x="day", data=tips, ax = ax[1])
plt.tight_layout()

# %% [markdown]
# ## BOXPLOT

# %%
sns.boxplot(x = "day", y = "total_bill", data = tips);

# %%
sns.boxplot(x = "day", y = "total_bill", data = tips, hue = "sex")

plt.legend(bbox_to_anchor = (1.05, 1), loc = 2, borderaxespad = 0.);

# %%
plt.figure(figsize = (14, 8))

sns.boxplot(x = "day", y = "total_bill", data = tips, hue = "sex");

# %%
plt.figure(figsize = (14, 8))

sns.boxplot(x = "total_bill", y = "day", data = tips, hue = "sex", orient ="h");

# %%
plt.figure(figsize=(14,5))
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex',width=0.3);

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.boxplot(x = "parental level of education", y = "math score", data = df)

ploe = df["parental level of education"].value_counts()
ploe_pos = range(len(ploe.index))
plt.xticks(ploe_pos, ploe.index, rotation=45);

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='parental level of education',y='math score',data=df,hue='gender')
# Optional move the legend outside
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.xticks(rotation = 'vertical');

# %% [markdown]
# ## VIOLINPLOT

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips, hue = "sex");

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips, hue = "sex", split = True);

# %%
# oriantation,  just change x and y, you don't need orient param
#################################################################################
plt.figure(figsize=(9,6))
sns.violinplot(y='day', x="total_bill",data=tips, hue="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips, hue = "sex", split = True, bw = 0.2);

# %% [markdown]
# ## SWARMPLOT

# %%
sns.swarmplot(x="day",y="total_bill",data=tips);

# %%
sns.swarmplot(x = "total_bill",data=tips);

# %%
sns.swarmplot(y="smoker", x="total_bill",data=tips);

# %%
sns.swarmplot(y="smoker", x="total_bill", hue = "sex" , data=tips);

# %%
sns.swarmplot(y="smoker", x="total_bill", hue = "sex" , data=tips, dodge = True);

# %%
df = pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
sns.swarmplot(y="race/ethnicity", x="math score", hue = "gender" , data=df);
# Out:
# C:\Users\BAHAR\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 21.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\BAHAR\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 39.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\BAHAR\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 30.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## BOXENPLOT

# %%
sns.boxenplot(x = "math score", y = "race/ethnicity", data = df, hue = "gender")
# Out:
# <AxesSubplot:xlabel='math score', ylabel='race/ethnicity'>

# %%
print(sns.get_dataset_names())
flights = sns.load_dataset("flights")
flights
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
f_sum = flights.groupby(["year", "month"]).sum()
f_sum
# Out:
#             passengers
# year month
# 1949 Jan           112
#      Feb           118
#      Mar           132
#      Apr           129
#      May           121
# ...                ...
# 1960 Aug           606
#      Sep           508
#      Oct           461
#      Nov           390
#      Dec           432
#
# [144 rows x 1 columns]

# %%
sns.lineplot(y = f_sum.passengers, x = f_sum.reset_index().index)
# Out:
# <AxesSubplot:ylabel='passengers'>

# %%
flights_wide = flights.pivot(index = "year", columns = "month", values = "passengers")
flights_wide
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.lineplot(data = flights_wide)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.lineplot(data=flights, x="year", y="passengers", hue="month")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %% [markdown]
# ## mehmetfatihdata
